# %% [markdown]
# Input():It is a function used to take input from the user at runtime.

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a= input("Enter value: ")#default value is string
print(a)
print(type(a))
# Out:
# Enter value:  int
# int
# <class 'str'>

# %%
a1=input("Enter 1st value: ")
a2=input("Enter 2nd value: ")
a3=a1+a2
print(a3)#concates if int is not used
# Out:
# Enter 1st value:  10
# Enter 2nd value:  30
# 1030

# %%
a1=int(input("Enter 1st value: "))
a2=int(input("Enter 2nd value: "))
a3=a1+a2
print(a3)
# Out:
# Enter 1st value:  55
# Enter 2nd value:  77
# 132

# %%
s= input(int)
print(s)
# Out:
# <class 'int'> 1
# 1
