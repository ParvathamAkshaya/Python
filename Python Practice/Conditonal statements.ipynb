# %% [markdown]
# CONDITIONAL STATEMENTS
# It is used to make decisions based on condition.
# if
# if-else
# if-elif-if

# %%
age=18
if age >=18:
    print("You are eligible for vote")
# Out:
# You are eligible for vote

# %%
age=15
if age >=18:
    print("You are eligible for vote")
else:
     print("You are not eligible for vote")
# Out:
# You are not eligible for vote

# %%
marks=45
if marks>=50:
    print("A-grade")
elif marks>=30:
     print("b-grade")
else:
     print("c-grade")
# Out:
# b-grade

# %%
name = input ("enter value:")
if name == 'python'or name == 'Python':#what condition we give based on that it execute
    print ("hey this is python class")
print("Bye!!")
# Out:
# enter value: python
# hey this is python class
# Bye!!

# %%
username="akki"
pwd= 1234
if username == "akki":
    if pwd== 1234:
        print("login sucessfull")
    else:
      print("Invalid credentials")
# Out:
# login sucessfull

# %%
#nested if-else block
atm= 'card'
pwd= 1234
bank= 'sbi'
balance= 50000
withdraw= 5000
if atm == 'card':
    if pwd == 1234:
        if bank == 'sbi':
            if withdraw <= balance:
                print("transaction success")
            else:
                print("insufficient balance")
        else:
              print("invalid bank credentials")
    else:
        print("invalid password")
else:
    print("insert card properly")
# Out:
# transaction success

# %%
exp=10
if exp>= 0 and exp<2:
    print("data analyst")
elif exp >= 4 and exp <= 8:
    print("senior data analyst")
else:
    print("manager")
# Out:
# manager
