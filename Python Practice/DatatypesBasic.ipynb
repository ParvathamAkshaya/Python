# %%
a=10

# %%
a
# Out:
# 10

# %%
a=10
b=20
c=a+b

c
# Out:
# 30

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
_total=20

# %%
_total
# Out:
# 20

# %%
total=21

# %%
total
# Out:
# 21

# %%
FUNDAMENTAL DATA TYPES

# %%
#INT
a=10
print(a)# print is the function used to display output on the screen
type(a)# type is a function to check which type of data it is storing
# Out:
# 10
# int

# %%
#FLOAT
b=10.3
print(b)
type(b)
# Out:
# 10.3
# float

# %%
#complex
c=4+10j
print(c)
type(c)
# Out:
# (4+10j)
# complex

# %%
#string
d="python"
d
# Out:
# 'python'

# %%
a="abc"
b='abcd'
print(a)
print(b)
print("type of a:",type(a))
# Out:
# abc
# abcd
# type of a: <class 'str'>

# %%
#boolean
a = True
type(a)
# Out:
# bool

# %%
OTHER DATATYPES

# %%
print(type(1j), type(["apple","banana","cherry"]), type(("apple","banana","cherry")),
      type(range(6)), type({"name":"John","age":36}), type({"apple","banana","cherry"}),
      type(frozenset({"apple","banana","cherry"})), type(True), type(b"Hello"),
      type(bytearray(5)), type(memoryview(bytes(5))), type(None))
# Out:
# <class 'complex'> <class 'list'> <class 'tuple'> <class 'range'> <class 'dict'> <class 'set'> <class 'frozenset'> <class 'bool'> <class 'bytes'> <class 'bytearray'> <class 'memoryview'> <class 'NoneType'>

# %%
a=(["apple","grapes"])
print(a)
type(a)
# Out:
# ['apple', 'grapes']
# list

# %%
a=()
print()

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
#semicolon(;)
print('hiis');print('ajds');print('jdsjn')
# Out:
# hiis
# ajds
# jdsjn

# %%
#print without new line
print("helloworld!",end=" ")
print("this is python notes.")
# Out:
# helloworld! this is python notes.

# %%
#numbers
print(3+5)
print(3*5)
# Out:
# 8
# 15

# %%
print("i am",23,"years old!")
# Out:
# i am 23 years old!

# %%
"""
this is comment
more than
one line
"""
print("hi")
# Out:
# hi

# %%
#Assigning 3 variables in one statement
x=y=z='hello world!'
print(x)
print(y)
print(z)
# Out:
# hello world!
# hello world!
# hello world!

# %%
x,y,z="orange","banana","grapes"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# grapes

# %%
cars="bmw","benz","toyota"
a,b,c=cars
print(a)
print(b)
print(c)
# Out:
# bmw
# benz
# toyota

# %%
x="python"
y="is"
z="awsome"
print(x,y,z)#can also use + instead of , but only str or int..both means no eg:3+jhon
# Out:
# python is awsome

# %%
#global variable
x="awesome"

def myfunc():
    print("python is " + x)
myfunc()
# Out:
# python is awesome

# %%
x="awesome"
def myfunc():
    x="good to learn"
    print("python is " + x)
myfunc()
print("python is " + x)
# Out:
# python is good to learn
# python is awesome

# %%
#slicing string
b="hello,world!"
print(b[3:9])
# Out:
# lo,wor

# %%
#modify strings
a="Hello ,world!"
print(a.upper())
print(a.lower())
print(a.strip())
print(a.split(","))
print(a.replace("H","d"))
# Out:
# HELLO ,WORLD!
# hello ,world!
# Hello ,world!
# ['Hello ', 'world!']
# dello ,world!

# %%
#concate
a="hello"
b="world"
c=a+" "+b
print(c)
# Out:
# hello world

# %%
#formating string(f)
price=56
tx=f"The price is {price} dollers"
txt=f"The price is {price:.2f} dollers"#.2f fixed point number with 2 decimals
ttxt=f"The price is {20*45} dollers"
print(tx)
print(txt)
print(ttxt)
# Out:
# The price is 56 dollers
# The price is 56.00 dollers
# The price is 900 dollers

# %%
a=100
b=200
if a>b:
    print("a is greater than b")
else:
    print("a is not greater than b")
# Out:
# a is not greater than b

# %%
#isinstance function used to determine certain datatype
a=200
b=455
print(isinstance(a,int))
print(isinstance(b,str))
# Out:
# True
# False
